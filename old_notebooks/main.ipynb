# %%
import pandas as pd
from scripts.sequence_stuff import *
from scripts.plots import *
from scripts.collector import *
from scripts.filtering import *

# %%
specific_file = 'data/long_reads/GRIA-CNS-RESUB.C0x1291.aligned.sorted.MinRQ998.reads.degenerate.csv'
sequences = pd.read_csv(specific_file)['Sequence'].values
filter = Filter(sequences)

# %%
final_working_sequences, final_picked_sequences, history = filter.do_filter()
# Out:
# Checking for k=1
# Checking for k=2
# Checking for k=3
# Checking for k=4
# Checking for k=5
# Checking for k=6
# Finding uncovered sequences
# Checking sequence 0/31233, 0 covered, 0 uncovered
# Checking sequence 100/31233, 4 covered, 96 uncovered
# Checking sequence 200/31233, 6 covered, 194 uncovered
# Checking sequence 300/31233, 6 covered, 294 uncovered
# Checking sequence 400/31233, 6 covered, 394 uncovered
# Checking sequence 500/31233, 7 covered, 493 uncovered
# Checking sequence 600/31233, 10 covered, 590 uncovered
# Checking sequence 700/31233, 10 covered, 690 uncovered
# Checking sequence 800/31233, 13 covered, 787 uncovered
# Checking sequence 900/31233, 15 covered, 885 uncovered
# Checking sequence 1000/31233, 16 covered, 984 uncovered
# Checking sequence 1100/31233, 17 covered, 1083 uncovered
# Checking sequence 1200/31233, 20 covered, 1180 uncovered
# Checking sequence 1300/31233, 23 covered, 1277 uncovered
# Checking sequence 1400/31233, 26 covered, 1374 uncovered
# ...

# %%
filter.save_picked_csv('data/long_reads/GRIA-CNS-RESUB.C0x1291.aligned.sorted.MinRQ998.reads.degenerate.filtered_picked.csv')
filter.save_working_csv('data/long_reads/GRIA-CNS-RESUB.C0x1291.aligned.sorted.MinRQ998.reads.degenerate.filtered_working.csv')

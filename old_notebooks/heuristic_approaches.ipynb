# %%
import networkx as nx
import pandas as pd
from scripts.sequence_stuff import *
from scripts.plots import *
from scripts.collector import *
from scripts.filtering import *
from scripts.graph_stuff import *

# %%
#specific_file = 'data/long_reads/GRIA-CNS-RESUB.C0x1291.aligned.sorted.MinRQ998.reads.degenerate.csv'
specific_file = 'data/long_reads/PCLO-CNS-RESUB.C0x1291.aligned.sorted.MinRQ998.reads.degenerate.csv'

sequences = pd.read_csv(specific_file)['Sequence'].values
collector=  SequenceCollector(sequences)
collector.update()

uncovered_sequences = collector.get_working_sequences()
# Out:
# Finding uncovered sequences
# Checking sequence 0/52619, 0 covered, 0 uncovered
# Checking sequence 100/52619, 14 covered, 86 uncovered
# Checking sequence 200/52619, 23 covered, 177 uncovered
# Checking sequence 300/52619, 31 covered, 269 uncovered
# Checking sequence 400/52619, 38 covered, 362 uncovered
# Checking sequence 500/52619, 46 covered, 454 uncovered
# Checking sequence 600/52619, 55 covered, 545 uncovered
# Checking sequence 700/52619, 64 covered, 636 uncovered
# Checking sequence 800/52619, 67 covered, 733 uncovered
# Checking sequence 900/52619, 74 covered, 826 uncovered
# Checking sequence 1000/52619, 80 covered, 920 uncovered
# Checking sequence 1100/52619, 84 covered, 1016 uncovered
# Checking sequence 1200/52619, 90 covered, 1110 uncovered
# Checking sequence 1300/52619, 99 covered, 1201 uncovered
# Checking sequence 1400/52619, 105 covered, 1295 uncovered
# Checking sequence 1500/52619, 110 covered, 1390 uncovered
# Checking sequence 1600/52619, 112 covered, 1488 uncovered
# Checking sequence 1700/52619, 119 covered, 1581 uncovered
# Checking sequence 1800/52619, 126 covered, 1674 uncovered
# Checking sequence 1900/52619, 131 covered, 1769 uncovered
# Checking sequence 2000/52619, 137 covered, 1863 uncovered
# Checking sequence 2100/52619, 146 covered, 1954 uncovered
# Checking sequence 2200/52619, 151 covered, 2049 uncovered
# Checking sequence 2300/52619, 159 covered, 2141 uncovered
# Checking sequence 2400/52619, 169 covered, 2231 uncovered
# Checking sequence 2500/52619, 174 covered, 2326 uncovered
# Checking sequence 2600/52619, 184 covered, 2416 uncovered
# Checking sequence 2700/52619, 194 covered, 2506 uncovered
# Checking sequence 2800/52619, 199 covered, 2601 uncovered
# Checking sequence 2900/52619, 206 covered, 2694 uncovered
# Checking sequence 3000/52619, 217 covered, 2783 uncovered
# Checking sequence 3100/52619, 224 covered, 2876 uncovered
# Checking sequence 3200/52619, 233 covered, 2967 uncovered
# Checking sequence 3300/52619, 241 covered, 3059 uncovered
# Checking sequence 3400/52619, 250 covered, 3150 uncovered
# Checking sequence 3500/52619, 259 covered, 3241 uncovered
# Checking sequence 3600/52619, 271 covered, 3329 uncovered
# Checking sequence 3700/52619, 278 covered, 3422 uncovered
# Checking sequence 3800/52619, 285 covered, 3515 uncovered
# Checking sequence 3900/52619, 291 covered, 3609 uncovered
# Checking sequence 4000/52619, 299 covered, 3701 uncovered
# Checking sequence 4100/52619, 305 covered, 3795 uncovered
# Checking sequence 4200/52619, 309 covered, 3891 uncovered
# Checking sequence 4300/52619, 320 covered, 3980 uncovered
# Checking sequence 4400/52619, 330 covered, 4070 uncovered
# Checking sequence 4500/52619, 337 covered, 4163 uncovered
# Checking sequence 4600/52619, 342 covered, 4258 uncovered
# Checking sequence 4700/52619, 345 covered, 4355 uncovered
# Checking sequence 4800/52619, 353 covered, 4447 uncovered
# Checking sequence 4900/52619, 356 covered, 4544 uncovered
# Checking sequence 5000/52619, 365 covered, 4635 uncovered
# Checking sequence 5100/52619, 373 covered, 4727 uncovered
# Checking sequence 5200/52619, 379 covered, 4821 uncovered
# Checking sequence 5300/52619, 384 covered, 4916 uncovered
# Checking sequence 5400/52619, 390 covered, 5010 uncovered
# Checking sequence 5500/52619, 396 covered, 5104 uncovered
# Checking sequence 5600/52619, 401 covered, 5199 uncovered
# Checking sequence 5700/52619, 410 covered, 5290 uncovered
# Checking sequence 5800/52619, 415 covered, 5385 uncovered
# Checking sequence 5900/52619, 427 covered, 5473 uncovered
# Checking sequence 6000/52619, 433 covered, 5567 uncovered
# Checking sequence 6100/52619, 435 covered, 5665 uncovered
# Checking sequence 6200/52619, 443 covered, 5757 uncovered
# Checking sequence 6300/52619, 449 covered, 5851 uncovered
# Checking sequence 6400/52619, 457 covered, 5943 uncovered
# Checking sequence 6500/52619, 465 covered, 6035 uncovered
# Checking sequence 6600/52619, 468 covered, 6132 uncovered
# Checking sequence 6700/52619, 475 covered, 6225 uncovered
# Checking sequence 6800/52619, 478 covered, 6322 uncovered
# Checking sequence 6900/52619, 487 covered, 6413 uncovered
# Checking sequence 7000/52619, 494 covered, 6506 uncovered
# Checking sequence 7100/52619, 498 covered, 6602 uncovered
# Checking sequence 7200/52619, 509 covered, 6691 uncovered
# Checking sequence 7300/52619, 516 covered, 6784 uncovered
# Checking sequence 7400/52619, 525 covered, 6875 uncovered
# Checking sequence 7500/52619, 529 covered, 6971 uncovered
# Checking sequence 7600/52619, 537 covered, 7063 uncovered
# Checking sequence 7700/52619, 546 covered, 7154 uncovered
# Checking sequence 7800/52619, 552 covered, 7248 uncovered
# Checking sequence 7900/52619, 558 covered, 7342 uncovered
# Checking sequence 8000/52619, 565 covered, 7435 uncovered
# Checking sequence 8100/52619, 571 covered, 7529 uncovered
# Checking sequence 8200/52619, 579 covered, 7621 uncovered
# Checking sequence 8300/52619, 586 covered, 7714 uncovered
# Checking sequence 8400/52619, 592 covered, 7808 uncovered
# Checking sequence 8500/52619, 596 covered, 7904 uncovered
# Checking sequence 8600/52619, 606 covered, 7994 uncovered
# Checking sequence 8700/52619, 611 covered, 8089 uncovered
# Checking sequence 8800/52619, 618 covered, 8182 uncovered
# Checking sequence 8900/52619, 627 covered, 8273 uncovered
# Checking sequence 9000/52619, 634 covered, 8366 uncovered
# Checking sequence 9100/52619, 637 covered, 8463 uncovered
# Checking sequence 9200/52619, 642 covered, 8558 uncovered
# Checking sequence 9300/52619, 643 covered, 8657 uncovered
# Checking sequence 9400/52619, 650 covered, 8750 uncovered
# Checking sequence 9500/52619, 658 covered, 8842 uncovered
# Checking sequence 9600/52619, 663 covered, 8937 uncovered
# Checking sequence 9700/52619, 668 covered, 9032 uncovered
# Checking sequence 9800/52619, 676 covered, 9124 uncovered
# Checking sequence 9900/52619, 682 covered, 9218 uncovered
# Checking sequence 10000/52619, 693 covered, 9307 uncovered
# Checking sequence 10100/52619, 701 covered, 9399 uncovered
# Checking sequence 10200/52619, 708 covered, 9492 uncovered
# Checking sequence 10300/52619, 716 covered, 9584 uncovered
# Checking sequence 10400/52619, 725 covered, 9675 uncovered
# Checking sequence 10500/52619, 728 covered, 9772 uncovered
# Checking sequence 10600/52619, 732 covered, 9868 uncovered
# Checking sequence 10700/52619, 738 covered, 9962 uncovered
# Checking sequence 10800/52619, 744 covered, 10056 uncovered
# Checking sequence 10900/52619, 750 covered, 10150 uncovered
# Checking sequence 11000/52619, 759 covered, 10241 uncovered
# Checking sequence 11100/52619, 763 covered, 10337 uncovered
# Checking sequence 11200/52619, 766 covered, 10434 uncovered
# Checking sequence 11300/52619, 774 covered, 10526 uncovered
# Checking sequence 11400/52619, 779 covered, 10621 uncovered
# Checking sequence 11500/52619, 783 covered, 10717 uncovered
# Checking sequence 11600/52619, 786 covered, 10814 uncovered
# Checking sequence 11700/52619, 796 covered, 10904 uncovered
# Checking sequence 11800/52619, 802 covered, 10998 uncovered
# Checking sequence 11900/52619, 807 covered, 11093 uncovered
# Checking sequence 12000/52619, 816 covered, 11184 uncovered
# Checking sequence 12100/52619, 825 covered, 11275 uncovered
# Checking sequence 12200/52619, 830 covered, 11370 uncovered
# Checking sequence 12300/52619, 837 covered, 11463 uncovered
# Checking sequence 12400/52619, 842 covered, 11558 uncovered
# Checking sequence 12500/52619, 849 covered, 11651 uncovered
# Checking sequence 12600/52619, 855 covered, 11745 uncovered
# Checking sequence 12700/52619, 860 covered, 11840 uncovered
# Checking sequence 12800/52619, 868 covered, 11932 uncovered
# Checking sequence 12900/52619, 873 covered, 12027 uncovered
# Checking sequence 13000/52619, 880 covered, 12120 uncovered
# Checking sequence 13100/52619, 890 covered, 12210 uncovered
# Checking sequence 13200/52619, 899 covered, 12301 uncovered
# Checking sequence 13300/52619, 905 covered, 12395 uncovered
# Checking sequence 13400/52619, 912 covered, 12488 uncovered
# Checking sequence 13500/52619, 919 covered, 12581 uncovered
# Checking sequence 13600/52619, 922 covered, 12678 uncovered
# Checking sequence 13700/52619, 928 covered, 12772 uncovered
# Checking sequence 13800/52619, 930 covered, 12870 uncovered
# Checking sequence 13900/52619, 934 covered, 12966 uncovered
# Checking sequence 14000/52619, 940 covered, 13060 uncovered
# Checking sequence 14100/52619, 944 covered, 13156 uncovered
# Checking sequence 14200/52619, 951 covered, 13249 uncovered
# Checking sequence 14300/52619, 955 covered, 13345 uncovered
# Checking sequence 14400/52619, 960 covered, 13440 uncovered
# Checking sequence 14500/52619, 968 covered, 13532 uncovered
# Checking sequence 14600/52619, 973 covered, 13627 uncovered
# Checking sequence 14700/52619, 980 covered, 13720 uncovered
# Checking sequence 14800/52619, 987 covered, 13813 uncovered
# Checking sequence 14900/52619, 996 covered, 13904 uncovered
# Checking sequence 15000/52619, 1005 covered, 13995 uncovered
# Checking sequence 15100/52619, 1012 covered, 14088 uncovered
# Checking sequence 15200/52619, 1017 covered, 14183 uncovered
# Checking sequence 15300/52619, 1022 covered, 14278 uncovered
# Checking sequence 15400/52619, 1033 covered, 14367 uncovered
# Checking sequence 15500/52619, 1040 covered, 14460 uncovered
# Checking sequence 15600/52619, 1045 covered, 14555 uncovered
# Checking sequence 15700/52619, 1054 covered, 14646 uncovered
# Checking sequence 15800/52619, 1062 covered, 14738 uncovered
# Checking sequence 15900/52619, 1069 covered, 14831 uncovered
# Checking sequence 16000/52619, 1073 covered, 14927 uncovered
# Checking sequence 16100/52619, 1079 covered, 15021 uncovered
# Checking sequence 16200/52619, 1086 covered, 15114 uncovered
# Checking sequence 16300/52619, 1093 covered, 15207 uncovered
# Checking sequence 16400/52619, 1096 covered, 15304 uncovered
# Checking sequence 16500/52619, 1102 covered, 15398 uncovered
# Checking sequence 16600/52619, 1112 covered, 15488 uncovered
# Checking sequence 16700/52619, 1120 covered, 15580 uncovered
# Checking sequence 16800/52619, 1129 covered, 15671 uncovered
# Checking sequence 16900/52619, 1134 covered, 15766 uncovered
# Checking sequence 17000/52619, 1138 covered, 15862 uncovered
# Checking sequence 17100/52619, 1145 covered, 15955 uncovered
# Checking sequence 17200/52619, 1156 covered, 16044 uncovered
# Checking sequence 17300/52619, 1161 covered, 16139 uncovered
# Checking sequence 17400/52619, 1165 covered, 16235 uncovered
# Checking sequence 17500/52619, 1176 covered, 16324 uncovered
# Checking sequence 17600/52619, 1180 covered, 16420 uncovered
# Checking sequence 17700/52619, 1189 covered, 16511 uncovered
# Checking sequence 17800/52619, 1198 covered, 16602 uncovered
# Checking sequence 17900/52619, 1202 covered, 16698 uncovered
# Checking sequence 18000/52619, 1210 covered, 16790 uncovered
# Checking sequence 18100/52619, 1226 covered, 16874 uncovered
# Checking sequence 18200/52619, 1236 covered, 16964 uncovered
# Checking sequence 18300/52619, 1247 covered, 17053 uncovered
# Checking sequence 18400/52619, 1253 covered, 17147 uncovered
# Checking sequence 18500/52619, 1258 covered, 17242 uncovered
# Checking sequence 18600/52619, 1265 covered, 17335 uncovered
# Checking sequence 18700/52619, 1271 covered, 17429 uncovered
# Checking sequence 18800/52619, 1280 covered, 17520 uncovered
# Checking sequence 18900/52619, 1292 covered, 17608 uncovered
# Checking sequence 19000/52619, 1296 covered, 17704 uncovered
# Checking sequence 19100/52619, 1303 covered, 17797 uncovered
# Checking sequence 19200/52619, 1307 covered, 17893 uncovered
# Checking sequence 19300/52619, 1310 covered, 17990 uncovered
# Checking sequence 19400/52619, 1316 covered, 18084 uncovered
# Checking sequence 19500/52619, 1327 covered, 18173 uncovered
# Checking sequence 19600/52619, 1331 covered, 18269 uncovered
# Checking sequence 19700/52619, 1340 covered, 18360 uncovered
# Checking sequence 19800/52619, 1349 covered, 18451 uncovered
# Checking sequence 19900/52619, 1355 covered, 18545 uncovered
# Checking sequence 20000/52619, 1359 covered, 18641 uncovered
# Checking sequence 20100/52619, 1368 covered, 18732 uncovered
# Checking sequence 20200/52619, 1377 covered, 18823 uncovered
# Checking sequence 20300/52619, 1387 covered, 18913 uncovered
# Checking sequence 20400/52619, 1392 covered, 19008 uncovered
# Checking sequence 20500/52619, 1400 covered, 19100 uncovered
# Checking sequence 20600/52619, 1404 covered, 19196 uncovered
# Checking sequence 20700/52619, 1409 covered, 19291 uncovered
# Checking sequence 20800/52619, 1416 covered, 19384 uncovered
# Checking sequence 20900/52619, 1419 covered, 19481 uncovered
# Checking sequence 21000/52619, 1423 covered, 19577 uncovered
# Checking sequence 21100/52619, 1433 covered, 19667 uncovered
# Checking sequence 21200/52619, 1443 covered, 19757 uncovered
# Checking sequence 21300/52619, 1448 covered, 19852 uncovered
# Checking sequence 21400/52619, 1453 covered, 19947 uncovered
# Checking sequence 21500/52619, 1460 covered, 20040 uncovered
# Checking sequence 21600/52619, 1466 covered, 20134 uncovered
# Checking sequence 21700/52619, 1477 covered, 20223 uncovered
# Checking sequence 21800/52619, 1485 covered, 20315 uncovered
# Checking sequence 21900/52619, 1488 covered, 20412 uncovered
# Checking sequence 22000/52619, 1491 covered, 20509 uncovered
# Checking sequence 22100/52619, 1496 covered, 20604 uncovered
# Checking sequence 22200/52619, 1506 covered, 20694 uncovered
# Checking sequence 22300/52619, 1511 covered, 20789 uncovered
# Checking sequence 22400/52619, 1517 covered, 20883 uncovered
# Checking sequence 22500/52619, 1525 covered, 20975 uncovered
# Checking sequence 22600/52619, 1539 covered, 21061 uncovered
# Checking sequence 22700/52619, 1543 covered, 21157 uncovered
# Checking sequence 22800/52619, 1550 covered, 21250 uncovered
# Checking sequence 22900/52619, 1554 covered, 21346 uncovered
# Checking sequence 23000/52619, 1559 covered, 21441 uncovered
# Checking sequence 23100/52619, 1565 covered, 21535 uncovered
# Checking sequence 23200/52619, 1571 covered, 21629 uncovered
# Checking sequence 23300/52619, 1577 covered, 21723 uncovered
# Checking sequence 23400/52619, 1584 covered, 21816 uncovered
# Checking sequence 23500/52619, 1589 covered, 21911 uncovered
# Checking sequence 23600/52619, 1603 covered, 21997 uncovered
# Checking sequence 23700/52619, 1611 covered, 22089 uncovered
# Checking sequence 23800/52619, 1618 covered, 22182 uncovered
# Checking sequence 23900/52619, 1625 covered, 22275 uncovered
# Checking sequence 24000/52619, 1635 covered, 22365 uncovered
# Checking sequence 24100/52619, 1644 covered, 22456 uncovered
# Checking sequence 24200/52619, 1650 covered, 22550 uncovered
# Checking sequence 24300/52619, 1656 covered, 22644 uncovered
# Checking sequence 24400/52619, 1665 covered, 22735 uncovered
# Checking sequence 24500/52619, 1671 covered, 22829 uncovered
# Checking sequence 24600/52619, 1678 covered, 22922 uncovered
# Checking sequence 24700/52619, 1683 covered, 23017 uncovered
# Checking sequence 24800/52619, 1690 covered, 23110 uncovered
# Checking sequence 24900/52619, 1693 covered, 23207 uncovered
# Checking sequence 25000/52619, 1699 covered, 23301 uncovered
# Checking sequence 25100/52619, 1710 covered, 23390 uncovered
# Checking sequence 25200/52619, 1713 covered, 23487 uncovered
# Checking sequence 25300/52619, 1722 covered, 23578 uncovered
# Checking sequence 25400/52619, 1726 covered, 23674 uncovered
# Checking sequence 25500/52619, 1737 covered, 23763 uncovered
# Checking sequence 25600/52619, 1744 covered, 23856 uncovered
# Checking sequence 25700/52619, 1749 covered, 23951 uncovered
# Checking sequence 25800/52619, 1756 covered, 24044 uncovered
# Checking sequence 25900/52619, 1765 covered, 24135 uncovered
# Checking sequence 26000/52619, 1770 covered, 24230 uncovered
# Checking sequence 26100/52619, 1774 covered, 24326 uncovered
# Checking sequence 26200/52619, 1781 covered, 24419 uncovered
# Checking sequence 26300/52619, 1786 covered, 24514 uncovered
# Checking sequence 26400/52619, 1790 covered, 24610 uncovered
# Checking sequence 26500/52619, 1795 covered, 24705 uncovered
# Checking sequence 26600/52619, 1806 covered, 24794 uncovered
# Checking sequence 26700/52619, 1812 covered, 24888 uncovered
# Checking sequence 26800/52619, 1817 covered, 24983 uncovered
# Checking sequence 26900/52619, 1820 covered, 25080 uncovered
# Checking sequence 27000/52619, 1829 covered, 25171 uncovered
# Checking sequence 27100/52619, 1836 covered, 25264 uncovered
# Checking sequence 27200/52619, 1841 covered, 25359 uncovered
# Checking sequence 27300/52619, 1844 covered, 25456 uncovered
# Checking sequence 27400/52619, 1849 covered, 25551 uncovered
# Checking sequence 27500/52619, 1852 covered, 25648 uncovered
# Checking sequence 27600/52619, 1858 covered, 25742 uncovered
# Checking sequence 27700/52619, 1862 covered, 25838 uncovered
# Checking sequence 27800/52619, 1867 covered, 25933 uncovered
# Checking sequence 27900/52619, 1873 covered, 26027 uncovered
# Checking sequence 28000/52619, 1883 covered, 26117 uncovered
# Checking sequence 28100/52619, 1886 covered, 26214 uncovered
# Checking sequence 28200/52619, 1893 covered, 26307 uncovered
# Checking sequence 28300/52619, 1901 covered, 26399 uncovered
# Checking sequence 28400/52619, 1910 covered, 26490 uncovered
# Checking sequence 28500/52619, 1913 covered, 26587 uncovered
# Checking sequence 28600/52619, 1918 covered, 26682 uncovered
# Checking sequence 28700/52619, 1924 covered, 26776 uncovered
# Checking sequence 28800/52619, 1931 covered, 26869 uncovered
# Checking sequence 28900/52619, 1936 covered, 26964 uncovered
# Checking sequence 29000/52619, 1941 covered, 27059 uncovered
# Checking sequence 29100/52619, 1945 covered, 27155 uncovered
# Checking sequence 29200/52619, 1952 covered, 27248 uncovered
# Checking sequence 29300/52619, 1954 covered, 27346 uncovered
# Checking sequence 29400/52619, 1963 covered, 27437 uncovered
# Checking sequence 29500/52619, 1973 covered, 27527 uncovered
# Checking sequence 29600/52619, 1980 covered, 27620 uncovered
# Checking sequence 29700/52619, 1986 covered, 27714 uncovered
# Checking sequence 29800/52619, 1992 covered, 27808 uncovered
# Checking sequence 29900/52619, 1998 covered, 27902 uncovered
# Checking sequence 30000/52619, 2005 covered, 27995 uncovered
# Checking sequence 30100/52619, 2016 covered, 28084 uncovered
# Checking sequence 30200/52619, 2020 covered, 28180 uncovered
# Checking sequence 30300/52619, 2027 covered, 28273 uncovered
# Checking sequence 30400/52619, 2034 covered, 28366 uncovered
# Checking sequence 30500/52619, 2044 covered, 28456 uncovered
# Checking sequence 30600/52619, 2047 covered, 28553 uncovered
# Checking sequence 30700/52619, 2051 covered, 28649 uncovered
# Checking sequence 30800/52619, 2058 covered, 28742 uncovered
# Checking sequence 30900/52619, 2066 covered, 28834 uncovered
# Checking sequence 31000/52619, 2072 covered, 28928 uncovered
# Checking sequence 31100/52619, 2079 covered, 29021 uncovered
# Checking sequence 31200/52619, 2086 covered, 29114 uncovered
# Checking sequence 31300/52619, 2094 covered, 29206 uncovered
# Checking sequence 31400/52619, 2100 covered, 29300 uncovered
# Checking sequence 31500/52619, 2106 covered, 29394 uncovered
# Checking sequence 31600/52619, 2109 covered, 29491 uncovered
# Checking sequence 31700/52619, 2116 covered, 29584 uncovered
# Checking sequence 31800/52619, 2121 covered, 29679 uncovered
# Checking sequence 31900/52619, 2134 covered, 29766 uncovered
# Checking sequence 32000/52619, 2137 covered, 29863 uncovered
# Checking sequence 32100/52619, 2141 covered, 29959 uncovered
# Checking sequence 32200/52619, 2144 covered, 30056 uncovered
# Checking sequence 32300/52619, 2153 covered, 30147 uncovered
# Checking sequence 32400/52619, 2164 covered, 30236 uncovered
# Checking sequence 32500/52619, 2169 covered, 30331 uncovered
# Checking sequence 32600/52619, 2175 covered, 30425 uncovered
# Checking sequence 32700/52619, 2178 covered, 30522 uncovered
# Checking sequence 32800/52619, 2185 covered, 30615 uncovered
# Checking sequence 32900/52619, 2189 covered, 30711 uncovered
# Checking sequence 33000/52619, 2195 covered, 30805 uncovered
# Checking sequence 33100/52619, 2199 covered, 30901 uncovered
# Checking sequence 33200/52619, 2211 covered, 30989 uncovered
# Checking sequence 33300/52619, 2217 covered, 31083 uncovered
# Checking sequence 33400/52619, 2224 covered, 31176 uncovered
# Checking sequence 33500/52619, 2228 covered, 31272 uncovered
# Checking sequence 33600/52619, 2232 covered, 31368 uncovered
# Checking sequence 33700/52619, 2246 covered, 31454 uncovered
# Checking sequence 33800/52619, 2250 covered, 31550 uncovered
# Checking sequence 33900/52619, 2254 covered, 31646 uncovered
# Checking sequence 34000/52619, 2263 covered, 31737 uncovered
# Checking sequence 34100/52619, 2269 covered, 31831 uncovered
# Checking sequence 34200/52619, 2279 covered, 31921 uncovered
# Checking sequence 34300/52619, 2289 covered, 32011 uncovered
# Checking sequence 34400/52619, 2296 covered, 32104 uncovered
# Checking sequence 34500/52619, 2302 covered, 32198 uncovered
# Checking sequence 34600/52619, 2309 covered, 32291 uncovered
# Checking sequence 34700/52619, 2310 covered, 32390 uncovered
# Checking sequence 34800/52619, 2320 covered, 32480 uncovered
# Checking sequence 34900/52619, 2328 covered, 32572 uncovered
# Checking sequence 35000/52619, 2336 covered, 32664 uncovered
# Checking sequence 35100/52619, 2343 covered, 32757 uncovered
# Checking sequence 35200/52619, 2351 covered, 32849 uncovered
# Checking sequence 35300/52619, 2356 covered, 32944 uncovered
# Checking sequence 35400/52619, 2363 covered, 33037 uncovered
# Checking sequence 35500/52619, 2372 covered, 33128 uncovered
# Checking sequence 35600/52619, 2380 covered, 33220 uncovered
# Checking sequence 35700/52619, 2384 covered, 33316 uncovered
# Checking sequence 35800/52619, 2388 covered, 33412 uncovered
# Checking sequence 35900/52619, 2391 covered, 33509 uncovered
# Checking sequence 36000/52619, 2397 covered, 33603 uncovered
# Checking sequence 36100/52619, 2404 covered, 33696 uncovered
# Checking sequence 36200/52619, 2410 covered, 33790 uncovered
# Checking sequence 36300/52619, 2414 covered, 33886 uncovered
# Checking sequence 36400/52619, 2420 covered, 33980 uncovered
# Checking sequence 36500/52619, 2426 covered, 34074 uncovered
# Checking sequence 36600/52619, 2429 covered, 34171 uncovered
# Checking sequence 36700/52619, 2437 covered, 34263 uncovered
# Checking sequence 36800/52619, 2442 covered, 34358 uncovered
# Checking sequence 36900/52619, 2448 covered, 34452 uncovered
# Checking sequence 37000/52619, 2449 covered, 34551 uncovered
# Checking sequence 37100/52619, 2456 covered, 34644 uncovered
# Checking sequence 37200/52619, 2463 covered, 34737 uncovered
# Checking sequence 37300/52619, 2473 covered, 34827 uncovered
# Checking sequence 37400/52619, 2477 covered, 34923 uncovered
# Checking sequence 37500/52619, 2483 covered, 35017 uncovered
# Checking sequence 37600/52619, 2489 covered, 35111 uncovered
# Checking sequence 37700/52619, 2496 covered, 35204 uncovered
# Checking sequence 37800/52619, 2503 covered, 35297 uncovered
# Checking sequence 37900/52619, 2511 covered, 35389 uncovered
# Checking sequence 38000/52619, 2515 covered, 35485 uncovered
# Checking sequence 38100/52619, 2520 covered, 35580 uncovered
# Checking sequence 38200/52619, 2524 covered, 35676 uncovered
# Checking sequence 38300/52619, 2530 covered, 35770 uncovered
# Checking sequence 38400/52619, 2535 covered, 35865 uncovered
# Checking sequence 38500/52619, 2541 covered, 35959 uncovered
# Checking sequence 38600/52619, 2549 covered, 36051 uncovered
# Checking sequence 38700/52619, 2556 covered, 36144 uncovered
# Checking sequence 38800/52619, 2562 covered, 36238 uncovered
# Checking sequence 38900/52619, 2567 covered, 36333 uncovered
# Checking sequence 39000/52619, 2572 covered, 36428 uncovered
# Checking sequence 39100/52619, 2576 covered, 36524 uncovered
# Checking sequence 39200/52619, 2580 covered, 36620 uncovered
# Checking sequence 39300/52619, 2586 covered, 36714 uncovered
# Checking sequence 39400/52619, 2591 covered, 36809 uncovered
# Checking sequence 39500/52619, 2599 covered, 36901 uncovered
# Checking sequence 39600/52619, 2601 covered, 36999 uncovered
# Checking sequence 39700/52619, 2608 covered, 37092 uncovered
# Checking sequence 39800/52619, 2613 covered, 37187 uncovered
# Checking sequence 39900/52619, 2618 covered, 37282 uncovered
# Checking sequence 40000/52619, 2623 covered, 37377 uncovered
# Checking sequence 40100/52619, 2626 covered, 37474 uncovered
# Checking sequence 40200/52619, 2631 covered, 37569 uncovered
# Checking sequence 40300/52619, 2634 covered, 37666 uncovered
# Checking sequence 40400/52619, 2645 covered, 37755 uncovered
# Checking sequence 40500/52619, 2650 covered, 37850 uncovered
# Checking sequence 40600/52619, 2654 covered, 37946 uncovered
# Checking sequence 40700/52619, 2663 covered, 38037 uncovered
# Checking sequence 40800/52619, 2669 covered, 38131 uncovered
# Checking sequence 40900/52619, 2677 covered, 38223 uncovered
# Checking sequence 41000/52619, 2688 covered, 38312 uncovered
# Checking sequence 41100/52619, 2694 covered, 38406 uncovered
# Checking sequence 41200/52619, 2702 covered, 38498 uncovered
# Checking sequence 41300/52619, 2710 covered, 38590 uncovered
# Checking sequence 41400/52619, 2712 covered, 38688 uncovered
# Checking sequence 41500/52619, 2717 covered, 38783 uncovered
# Checking sequence 41600/52619, 2727 covered, 38873 uncovered
# Checking sequence 41700/52619, 2733 covered, 38967 uncovered
# Checking sequence 41800/52619, 2741 covered, 39059 uncovered
# Checking sequence 41900/52619, 2748 covered, 39152 uncovered
# Checking sequence 42000/52619, 2755 covered, 39245 uncovered
# Checking sequence 42100/52619, 2760 covered, 39340 uncovered
# Checking sequence 42200/52619, 2762 covered, 39438 uncovered
# Checking sequence 42300/52619, 2766 covered, 39534 uncovered
# Checking sequence 42400/52619, 2768 covered, 39632 uncovered
# Checking sequence 42500/52619, 2774 covered, 39726 uncovered
# Checking sequence 42600/52619, 2782 covered, 39818 uncovered
# Checking sequence 42700/52619, 2789 covered, 39911 uncovered
# Checking sequence 42800/52619, 2793 covered, 40007 uncovered
# Checking sequence 42900/52619, 2799 covered, 40101 uncovered
# Checking sequence 43000/52619, 2805 covered, 40195 uncovered
# Checking sequence 43100/52619, 2816 covered, 40284 uncovered
# Checking sequence 43200/52619, 2825 covered, 40375 uncovered
# Checking sequence 43300/52619, 2835 covered, 40465 uncovered
# Checking sequence 43400/52619, 2841 covered, 40559 uncovered
# Checking sequence 43500/52619, 2845 covered, 40655 uncovered
# Checking sequence 43600/52619, 2853 covered, 40747 uncovered
# Checking sequence 43700/52619, 2862 covered, 40838 uncovered
# Checking sequence 43800/52619, 2867 covered, 40933 uncovered
# Checking sequence 43900/52619, 2879 covered, 41021 uncovered
# Checking sequence 44000/52619, 2885 covered, 41115 uncovered
# Checking sequence 44100/52619, 2891 covered, 41209 uncovered
# Checking sequence 44200/52619, 2895 covered, 41305 uncovered
# Checking sequence 44300/52619, 2900 covered, 41400 uncovered
# Checking sequence 44400/52619, 2910 covered, 41490 uncovered
# Checking sequence 44500/52619, 2917 covered, 41583 uncovered
# Checking sequence 44600/52619, 2920 covered, 41680 uncovered
# Checking sequence 44700/52619, 2923 covered, 41777 uncovered
# Checking sequence 44800/52619, 2926 covered, 41874 uncovered
# Checking sequence 44900/52619, 2931 covered, 41969 uncovered
# Checking sequence 45000/52619, 2934 covered, 42066 uncovered
# Checking sequence 45100/52619, 2939 covered, 42161 uncovered
# Checking sequence 45200/52619, 2947 covered, 42253 uncovered
# Checking sequence 45300/52619, 2954 covered, 42346 uncovered
# Checking sequence 45400/52619, 2960 covered, 42440 uncovered
# Checking sequence 45500/52619, 2969 covered, 42531 uncovered
# Checking sequence 45600/52619, 2970 covered, 42630 uncovered
# Checking sequence 45700/52619, 2979 covered, 42721 uncovered
# Checking sequence 45800/52619, 2984 covered, 42816 uncovered
# Checking sequence 45900/52619, 2988 covered, 42912 uncovered
# Checking sequence 46000/52619, 2996 covered, 43004 uncovered
# Checking sequence 46100/52619, 3000 covered, 43100 uncovered
# Checking sequence 46200/52619, 3003 covered, 43197 uncovered
# Checking sequence 46300/52619, 3013 covered, 43287 uncovered
# Checking sequence 46400/52619, 3021 covered, 43379 uncovered
# Checking sequence 46500/52619, 3024 covered, 43476 uncovered
# Checking sequence 46600/52619, 3031 covered, 43569 uncovered
# Checking sequence 46700/52619, 3038 covered, 43662 uncovered
# Checking sequence 46800/52619, 3043 covered, 43757 uncovered
# Checking sequence 46900/52619, 3047 covered, 43853 uncovered
# Checking sequence 47000/52619, 3054 covered, 43946 uncovered
# Checking sequence 47100/52619, 3060 covered, 44040 uncovered
# Checking sequence 47200/52619, 3064 covered, 44136 uncovered
# Checking sequence 47300/52619, 3071 covered, 44229 uncovered
# Checking sequence 47400/52619, 3079 covered, 44321 uncovered
# Checking sequence 47500/52619, 3087 covered, 44413 uncovered
# Checking sequence 47600/52619, 3095 covered, 44505 uncovered
# Checking sequence 47700/52619, 3104 covered, 44596 uncovered
# Checking sequence 47800/52619, 3108 covered, 44692 uncovered
# Checking sequence 47900/52619, 3113 covered, 44787 uncovered
# Checking sequence 48000/52619, 3119 covered, 44881 uncovered
# Checking sequence 48100/52619, 3125 covered, 44975 uncovered
# Checking sequence 48200/52619, 3128 covered, 45072 uncovered
# Checking sequence 48300/52619, 3133 covered, 45167 uncovered
# Checking sequence 48400/52619, 3140 covered, 45260 uncovered
# Checking sequence 48500/52619, 3145 covered, 45355 uncovered
# Checking sequence 48600/52619, 3151 covered, 45449 uncovered
# Checking sequence 48700/52619, 3157 covered, 45543 uncovered
# Checking sequence 48800/52619, 3161 covered, 45639 uncovered
# Checking sequence 48900/52619, 3166 covered, 45734 uncovered
# Checking sequence 49000/52619, 3173 covered, 45827 uncovered
# Checking sequence 49100/52619, 3177 covered, 45923 uncovered
# Checking sequence 49200/52619, 3184 covered, 46016 uncovered
# Checking sequence 49300/52619, 3189 covered, 46111 uncovered
# Checking sequence 49400/52619, 3197 covered, 46203 uncovered
# Checking sequence 49500/52619, 3203 covered, 46297 uncovered
# Checking sequence 49600/52619, 3206 covered, 46394 uncovered
# Checking sequence 49700/52619, 3212 covered, 46488 uncovered
# Checking sequence 49800/52619, 3221 covered, 46579 uncovered
# Checking sequence 49900/52619, 3226 covered, 46674 uncovered
# Checking sequence 50000/52619, 3232 covered, 46768 uncovered
# Checking sequence 50100/52619, 3238 covered, 46862 uncovered
# Checking sequence 50200/52619, 3241 covered, 46959 uncovered
# Checking sequence 50300/52619, 3246 covered, 47054 uncovered
# Checking sequence 50400/52619, 3251 covered, 47149 uncovered
# Checking sequence 50500/52619, 3255 covered, 47245 uncovered
# Checking sequence 50600/52619, 3258 covered, 47342 uncovered
# Checking sequence 50700/52619, 3263 covered, 47437 uncovered
# Checking sequence 50800/52619, 3270 covered, 47530 uncovered
# Checking sequence 50900/52619, 3279 covered, 47621 uncovered
# Checking sequence 51000/52619, 3285 covered, 47715 uncovered
# Checking sequence 51100/52619, 3291 covered, 47809 uncovered
# Checking sequence 51200/52619, 3296 covered, 47904 uncovered
# Checking sequence 51300/52619, 3302 covered, 47998 uncovered
# Checking sequence 51400/52619, 3311 covered, 48089 uncovered
# Checking sequence 51500/52619, 3319 covered, 48181 uncovered
# Checking sequence 51600/52619, 3326 covered, 48274 uncovered
# Checking sequence 51700/52619, 3328 covered, 48372 uncovered
# Checking sequence 51800/52619, 3336 covered, 48464 uncovered
# Checking sequence 51900/52619, 3343 covered, 48557 uncovered
# Checking sequence 52000/52619, 3352 covered, 48648 uncovered
# Checking sequence 52100/52619, 3359 covered, 48741 uncovered
# Checking sequence 52200/52619, 3366 covered, 48834 uncovered
# Checking sequence 52300/52619, 3370 covered, 48930 uncovered
# Checking sequence 52400/52619, 3378 covered, 49022 uncovered
# Checking sequence 52500/52619, 3381 covered, 49119 uncovered
# Checking sequence 52600/52619, 3388 covered, 49212 uncovered

# %%
graph = build_graph(uncovered_sequences)
# Out:
# Adding edges for sequence 0/49229
# Adding edges for sequence 100/49229
# Adding edges for sequence 200/49229
# Adding edges for sequence 300/49229
# Adding edges for sequence 400/49229
# Adding edges for sequence 500/49229
# Adding edges for sequence 600/49229
# Adding edges for sequence 700/49229
# Adding edges for sequence 800/49229
# Adding edges for sequence 900/49229
# Adding edges for sequence 1000/49229
# Adding edges for sequence 1100/49229
# Adding edges for sequence 1200/49229
# Adding edges for sequence 1300/49229
# Adding edges for sequence 1400/49229
# Adding edges for sequence 1500/49229
# Adding edges for sequence 1600/49229
# Adding edges for sequence 1700/49229
# Adding edges for sequence 1800/49229
# Adding edges for sequence 1900/49229
# Adding edges for sequence 2000/49229
# Adding edges for sequence 2100/49229
# Adding edges for sequence 2200/49229
# Adding edges for sequence 2300/49229
# Adding edges for sequence 2400/49229
# Adding edges for sequence 2500/49229
# Adding edges for sequence 2600/49229
# Adding edges for sequence 2700/49229
# Adding edges for sequence 2800/49229
# Adding edges for sequence 2900/49229
# Adding edges for sequence 3000/49229
# Adding edges for sequence 3100/49229
# Adding edges for sequence 3200/49229
# Adding edges for sequence 3300/49229
# Adding edges for sequence 3400/49229
# Adding edges for sequence 3500/49229
# Adding edges for sequence 3600/49229
# Adding edges for sequence 3700/49229
# Adding edges for sequence 3800/49229
# Adding edges for sequence 3900/49229
# Adding edges for sequence 4000/49229
# Adding edges for sequence 4100/49229
# Adding edges for sequence 4200/49229
# Adding edges for sequence 4300/49229
# Adding edges for sequence 4400/49229
# Adding edges for sequence 4500/49229
# Adding edges for sequence 4600/49229
# Adding edges for sequence 4700/49229
# Adding edges for sequence 4800/49229
# Adding edges for sequence 4900/49229
# Adding edges for sequence 5000/49229
# Adding edges for sequence 5100/49229
# Adding edges for sequence 5200/49229
# Adding edges for sequence 5300/49229
# Adding edges for sequence 5400/49229
# Adding edges for sequence 5500/49229
# Adding edges for sequence 5600/49229
# Adding edges for sequence 5700/49229
# Adding edges for sequence 5800/49229
# Adding edges for sequence 5900/49229
# Adding edges for sequence 6000/49229
# Adding edges for sequence 6100/49229
# Adding edges for sequence 6200/49229
# Adding edges for sequence 6300/49229
# Adding edges for sequence 6400/49229
# Adding edges for sequence 6500/49229
# Adding edges for sequence 6600/49229
# Adding edges for sequence 6700/49229
# Adding edges for sequence 6800/49229
# Adding edges for sequence 6900/49229
# Adding edges for sequence 7000/49229
# Adding edges for sequence 7100/49229
# Adding edges for sequence 7200/49229
# Adding edges for sequence 7300/49229
# Adding edges for sequence 7400/49229
# Adding edges for sequence 7500/49229
# Adding edges for sequence 7600/49229
# Adding edges for sequence 7700/49229
# Adding edges for sequence 7800/49229
# Adding edges for sequence 7900/49229
# Adding edges for sequence 8000/49229
# Adding edges for sequence 8100/49229
# Adding edges for sequence 8200/49229
# Adding edges for sequence 8300/49229
# Adding edges for sequence 8400/49229
# Adding edges for sequence 8500/49229
# Adding edges for sequence 8600/49229
# Adding edges for sequence 8700/49229
# Adding edges for sequence 8800/49229
# Adding edges for sequence 8900/49229
# Adding edges for sequence 9000/49229
# Adding edges for sequence 9100/49229
# Adding edges for sequence 9200/49229
# Adding edges for sequence 9300/49229
# Adding edges for sequence 9400/49229
# Adding edges for sequence 9500/49229
# Adding edges for sequence 9600/49229
# Adding edges for sequence 9700/49229
# Adding edges for sequence 9800/49229
# Adding edges for sequence 9900/49229
# Adding edges for sequence 10000/49229
# Adding edges for sequence 10100/49229
# Adding edges for sequence 10200/49229
# Adding edges for sequence 10300/49229
# Adding edges for sequence 10400/49229
# Adding edges for sequence 10500/49229
# Adding edges for sequence 10600/49229
# Adding edges for sequence 10700/49229
# Adding edges for sequence 10800/49229
# Adding edges for sequence 10900/49229
# Adding edges for sequence 11000/49229
# Adding edges for sequence 11100/49229
# Adding edges for sequence 11200/49229
# Adding edges for sequence 11300/49229
# Adding edges for sequence 11400/49229
# Adding edges for sequence 11500/49229
# Adding edges for sequence 11600/49229
# Adding edges for sequence 11700/49229
# Adding edges for sequence 11800/49229
# Adding edges for sequence 11900/49229
# Adding edges for sequence 12000/49229
# Adding edges for sequence 12100/49229
# Adding edges for sequence 12200/49229
# Adding edges for sequence 12300/49229
# Adding edges for sequence 12400/49229
# Adding edges for sequence 12500/49229
# Adding edges for sequence 12600/49229
# Adding edges for sequence 12700/49229
# Adding edges for sequence 12800/49229
# Adding edges for sequence 12900/49229
# Adding edges for sequence 13000/49229
# Adding edges for sequence 13100/49229
# Adding edges for sequence 13200/49229
# Adding edges for sequence 13300/49229
# Adding edges for sequence 13400/49229
# Adding edges for sequence 13500/49229
# Adding edges for sequence 13600/49229
# Adding edges for sequence 13700/49229
# Adding edges for sequence 13800/49229
# Adding edges for sequence 13900/49229
# Adding edges for sequence 14000/49229
# Adding edges for sequence 14100/49229
# Adding edges for sequence 14200/49229
# Adding edges for sequence 14300/49229
# Adding edges for sequence 14400/49229
# Adding edges for sequence 14500/49229
# Adding edges for sequence 14600/49229
# Adding edges for sequence 14700/49229
# Adding edges for sequence 14800/49229
# Adding edges for sequence 14900/49229
# Adding edges for sequence 15000/49229
# Adding edges for sequence 15100/49229
# Adding edges for sequence 15200/49229
# Adding edges for sequence 15300/49229
# Adding edges for sequence 15400/49229
# Adding edges for sequence 15500/49229
# Adding edges for sequence 15600/49229
# Adding edges for sequence 15700/49229
# Adding edges for sequence 15800/49229
# Adding edges for sequence 15900/49229
# Adding edges for sequence 16000/49229
# Adding edges for sequence 16100/49229
# Adding edges for sequence 16200/49229
# Adding edges for sequence 16300/49229
# Adding edges for sequence 16400/49229
# Adding edges for sequence 16500/49229
# Adding edges for sequence 16600/49229
# Adding edges for sequence 16700/49229
# Adding edges for sequence 16800/49229
# Adding edges for sequence 16900/49229
# Adding edges for sequence 17000/49229
# Adding edges for sequence 17100/49229
# Adding edges for sequence 17200/49229
# Adding edges for sequence 17300/49229
# Adding edges for sequence 17400/49229
# Adding edges for sequence 17500/49229
# Adding edges for sequence 17600/49229
# Adding edges for sequence 17700/49229
# Adding edges for sequence 17800/49229
# Adding edges for sequence 17900/49229
# Adding edges for sequence 18000/49229
# Adding edges for sequence 18100/49229
# Adding edges for sequence 18200/49229
# Adding edges for sequence 18300/49229
# Adding edges for sequence 18400/49229
# Adding edges for sequence 18500/49229
# Adding edges for sequence 18600/49229
# Adding edges for sequence 18700/49229
# Adding edges for sequence 18800/49229
# Adding edges for sequence 18900/49229
# Adding edges for sequence 19000/49229
# Adding edges for sequence 19100/49229
# Adding edges for sequence 19200/49229
# Adding edges for sequence 19300/49229
# Adding edges for sequence 19400/49229
# Adding edges for sequence 19500/49229
# Adding edges for sequence 19600/49229
# Adding edges for sequence 19700/49229
# Adding edges for sequence 19800/49229
# Adding edges for sequence 19900/49229
# Adding edges for sequence 20000/49229
# Adding edges for sequence 20100/49229
# Adding edges for sequence 20200/49229
# Adding edges for sequence 20300/49229
# Adding edges for sequence 20400/49229
# Adding edges for sequence 20500/49229
# Adding edges for sequence 20600/49229
# Adding edges for sequence 20700/49229
# Adding edges for sequence 20800/49229
# Adding edges for sequence 20900/49229
# Adding edges for sequence 21000/49229
# Adding edges for sequence 21100/49229
# Adding edges for sequence 21200/49229
# Adding edges for sequence 21300/49229
# Adding edges for sequence 21400/49229
# Adding edges for sequence 21500/49229
# Adding edges for sequence 21600/49229
# Adding edges for sequence 21700/49229
# Adding edges for sequence 21800/49229
# Adding edges for sequence 21900/49229
# Adding edges for sequence 22000/49229
# Adding edges for sequence 22100/49229
# Adding edges for sequence 22200/49229
# Adding edges for sequence 22300/49229
# Adding edges for sequence 22400/49229
# Adding edges for sequence 22500/49229
# Adding edges for sequence 22600/49229
# Adding edges for sequence 22700/49229
# Adding edges for sequence 22800/49229
# Adding edges for sequence 22900/49229
# Adding edges for sequence 23000/49229
# Adding edges for sequence 23100/49229
# Adding edges for sequence 23200/49229
# Adding edges for sequence 23300/49229
# Adding edges for sequence 23400/49229
# Adding edges for sequence 23500/49229
# Adding edges for sequence 23600/49229
# Adding edges for sequence 23700/49229
# Adding edges for sequence 23800/49229
# Adding edges for sequence 23900/49229
# Adding edges for sequence 24000/49229
# Adding edges for sequence 24100/49229
# Adding edges for sequence 24200/49229
# Adding edges for sequence 24300/49229
# Adding edges for sequence 24400/49229
# Adding edges for sequence 24500/49229
# Adding edges for sequence 24600/49229
# Adding edges for sequence 24700/49229
# Adding edges for sequence 24800/49229
# Adding edges for sequence 24900/49229
# Adding edges for sequence 25000/49229
# Adding edges for sequence 25100/49229
# Adding edges for sequence 25200/49229
# Adding edges for sequence 25300/49229
# Adding edges for sequence 25400/49229
# Adding edges for sequence 25500/49229
# Adding edges for sequence 25600/49229
# Adding edges for sequence 25700/49229
# Adding edges for sequence 25800/49229
# Adding edges for sequence 25900/49229
# Adding edges for sequence 26000/49229
# Adding edges for sequence 26100/49229
# Adding edges for sequence 26200/49229
# Adding edges for sequence 26300/49229
# Adding edges for sequence 26400/49229
# Adding edges for sequence 26500/49229
# Adding edges for sequence 26600/49229
# Adding edges for sequence 26700/49229
# Adding edges for sequence 26800/49229
# Adding edges for sequence 26900/49229
# Adding edges for sequence 27000/49229
# Adding edges for sequence 27100/49229
# Adding edges for sequence 27200/49229
# Adding edges for sequence 27300/49229
# Adding edges for sequence 27400/49229
# Adding edges for sequence 27500/49229
# Adding edges for sequence 27600/49229
# Adding edges for sequence 27700/49229
# Adding edges for sequence 27800/49229
# Adding edges for sequence 27900/49229
# Adding edges for sequence 28000/49229
# Adding edges for sequence 28100/49229
# Adding edges for sequence 28200/49229
# Adding edges for sequence 28300/49229
# Adding edges for sequence 28400/49229
# Adding edges for sequence 28500/49229
# Adding edges for sequence 28600/49229
# Adding edges for sequence 28700/49229
# Adding edges for sequence 28800/49229
# Adding edges for sequence 28900/49229
# Adding edges for sequence 29000/49229
# Adding edges for sequence 29100/49229
# Adding edges for sequence 29200/49229
# Adding edges for sequence 29300/49229
# Adding edges for sequence 29400/49229
# Adding edges for sequence 29500/49229
# Adding edges for sequence 29600/49229
# Adding edges for sequence 29700/49229
# Adding edges for sequence 29800/49229
# Adding edges for sequence 29900/49229
# Adding edges for sequence 30000/49229
# Adding edges for sequence 30100/49229
# Adding edges for sequence 30200/49229
# Adding edges for sequence 30300/49229
# Adding edges for sequence 30400/49229
# Adding edges for sequence 30500/49229
# Adding edges for sequence 30600/49229
# Adding edges for sequence 30700/49229
# Adding edges for sequence 30800/49229
# Adding edges for sequence 30900/49229
# Adding edges for sequence 31000/49229
# Adding edges for sequence 31100/49229
# Adding edges for sequence 31200/49229
# Adding edges for sequence 31300/49229
# Adding edges for sequence 31400/49229
# Adding edges for sequence 31500/49229
# Adding edges for sequence 31600/49229
# Adding edges for sequence 31700/49229
# Adding edges for sequence 31800/49229
# Adding edges for sequence 31900/49229
# Adding edges for sequence 32000/49229
# Adding edges for sequence 32100/49229
# Adding edges for sequence 32200/49229
# Adding edges for sequence 32300/49229
# Adding edges for sequence 32400/49229
# Adding edges for sequence 32500/49229
# Adding edges for sequence 32600/49229
# Adding edges for sequence 32700/49229
# Adding edges for sequence 32800/49229
# Adding edges for sequence 32900/49229
# Adding edges for sequence 33000/49229
# Adding edges for sequence 33100/49229
# Adding edges for sequence 33200/49229
# Adding edges for sequence 33300/49229
# Adding edges for sequence 33400/49229
# Adding edges for sequence 33500/49229
# Adding edges for sequence 33600/49229
# Adding edges for sequence 33700/49229
# Adding edges for sequence 33800/49229
# Adding edges for sequence 33900/49229
# Adding edges for sequence 34000/49229
# Adding edges for sequence 34100/49229
# Adding edges for sequence 34200/49229
# Adding edges for sequence 34300/49229
# Adding edges for sequence 34400/49229
# Adding edges for sequence 34500/49229
# Adding edges for sequence 34600/49229
# Adding edges for sequence 34700/49229
# Adding edges for sequence 34800/49229
# Adding edges for sequence 34900/49229
# Adding edges for sequence 35000/49229
# Adding edges for sequence 35100/49229
# Adding edges for sequence 35200/49229
# Adding edges for sequence 35300/49229
# Adding edges for sequence 35400/49229
# Adding edges for sequence 35500/49229
# Adding edges for sequence 35600/49229
# Adding edges for sequence 35700/49229
# Adding edges for sequence 35800/49229
# Adding edges for sequence 35900/49229
# Adding edges for sequence 36000/49229
# Adding edges for sequence 36100/49229
# Adding edges for sequence 36200/49229
# Adding edges for sequence 36300/49229
# Adding edges for sequence 36400/49229
# Adding edges for sequence 36500/49229
# Adding edges for sequence 36600/49229
# Adding edges for sequence 36700/49229
# Adding edges for sequence 36800/49229
# Adding edges for sequence 36900/49229
# Adding edges for sequence 37000/49229
# Adding edges for sequence 37100/49229
# Adding edges for sequence 37200/49229
# Adding edges for sequence 37300/49229
# Adding edges for sequence 37400/49229
# Adding edges for sequence 37500/49229
# Adding edges for sequence 37600/49229
# Adding edges for sequence 37700/49229
# Adding edges for sequence 37800/49229
# Adding edges for sequence 37900/49229
# Adding edges for sequence 38000/49229
# Adding edges for sequence 38100/49229
# Adding edges for sequence 38200/49229
# Adding edges for sequence 38300/49229
# Adding edges for sequence 38400/49229
# Adding edges for sequence 38500/49229
# Adding edges for sequence 38600/49229
# Adding edges for sequence 38700/49229
# Adding edges for sequence 38800/49229
# Adding edges for sequence 38900/49229
# Adding edges for sequence 39000/49229
# Adding edges for sequence 39100/49229
# Adding edges for sequence 39200/49229
# Adding edges for sequence 39300/49229
# Adding edges for sequence 39400/49229
# Adding edges for sequence 39500/49229
# Adding edges for sequence 39600/49229
# Adding edges for sequence 39700/49229
# Adding edges for sequence 39800/49229
# Adding edges for sequence 39900/49229
# Adding edges for sequence 40000/49229
# Adding edges for sequence 40100/49229
# Adding edges for sequence 40200/49229
# Adding edges for sequence 40300/49229
# Adding edges for sequence 40400/49229
# Adding edges for sequence 40500/49229
# Adding edges for sequence 40600/49229
# Adding edges for sequence 40700/49229
# Adding edges for sequence 40800/49229
# Adding edges for sequence 40900/49229
# Adding edges for sequence 41000/49229
# Adding edges for sequence 41100/49229
# Adding edges for sequence 41200/49229
# Adding edges for sequence 41300/49229
# Adding edges for sequence 41400/49229
# Adding edges for sequence 41500/49229
# Adding edges for sequence 41600/49229
# Adding edges for sequence 41700/49229
# Adding edges for sequence 41800/49229
# Adding edges for sequence 41900/49229
# Adding edges for sequence 42000/49229
# Adding edges for sequence 42100/49229
# Adding edges for sequence 42200/49229
# Adding edges for sequence 42300/49229
# Adding edges for sequence 42400/49229
# Adding edges for sequence 42500/49229
# Adding edges for sequence 42600/49229
# Adding edges for sequence 42700/49229
# Adding edges for sequence 42800/49229
# Adding edges for sequence 42900/49229
# Adding edges for sequence 43000/49229
# Adding edges for sequence 43100/49229
# Adding edges for sequence 43200/49229
# Adding edges for sequence 43300/49229
# Adding edges for sequence 43400/49229
# Adding edges for sequence 43500/49229
# Adding edges for sequence 43600/49229
# Adding edges for sequence 43700/49229
# Adding edges for sequence 43800/49229
# Adding edges for sequence 43900/49229
# Adding edges for sequence 44000/49229
# Adding edges for sequence 44100/49229
# Adding edges for sequence 44200/49229
# Adding edges for sequence 44300/49229
# Adding edges for sequence 44400/49229
# Adding edges for sequence 44500/49229
# Adding edges for sequence 44600/49229
# Adding edges for sequence 44700/49229
# Adding edges for sequence 44800/49229
# Adding edges for sequence 44900/49229
# Adding edges for sequence 45000/49229
# Adding edges for sequence 45100/49229
# Adding edges for sequence 45200/49229
# Adding edges for sequence 45300/49229
# Adding edges for sequence 45400/49229
# Adding edges for sequence 45500/49229
# Adding edges for sequence 45600/49229
# Adding edges for sequence 45700/49229
# Adding edges for sequence 45800/49229
# Adding edges for sequence 45900/49229
# Adding edges for sequence 46000/49229
# Adding edges for sequence 46100/49229
# Adding edges for sequence 46200/49229
# Adding edges for sequence 46300/49229
# Adding edges for sequence 46400/49229
# Adding edges for sequence 46500/49229
# Adding edges for sequence 46600/49229
# Adding edges for sequence 46700/49229
# Adding edges for sequence 46800/49229
# Adding edges for sequence 46900/49229
# Adding edges for sequence 47000/49229
# Adding edges for sequence 47100/49229
# Adding edges for sequence 47200/49229
# Adding edges for sequence 47300/49229
# Adding edges for sequence 47400/49229
# Adding edges for sequence 47500/49229
# Adding edges for sequence 47600/49229
# Adding edges for sequence 47700/49229
# Adding edges for sequence 47800/49229
# Adding edges for sequence 47900/49229
# Adding edges for sequence 48000/49229
# Adding edges for sequence 48100/49229
# Adding edges for sequence 48200/49229
# Adding edges for sequence 48300/49229
# Adding edges for sequence 48400/49229
# Adding edges for sequence 48500/49229
# Adding edges for sequence 48600/49229
# Adding edges for sequence 48700/49229
# Adding edges for sequence 48800/49229
# Adding edges for sequence 48900/49229
# Adding edges for sequence 49000/49229
# Adding edges for sequence 49100/49229
# Adding edges for sequence 49200/49229

# %% [markdown]
# # Lower Bound - Maximal IS

# %%
def maximal_independent_set(G):
    # Create an empty set for the independent set
    independent_set = set()

    # Sort the nodes by degree in ascending order
    sorted_nodes = sorted(G.nodes(), key=lambda x: G.degree(x))

    # Add nodes to the independent set one by one
    for node in sorted_nodes:
        # Check if the node can be added to the independent set
        if all(neighbor not in independent_set for neighbor in G.neighbors(node)):
            independent_set.add(node)
    
    return independent_set

indepedent_set = maximal_independent_set(graph)
print(len(indepedent_set))
# Out:
# 26729

# %% [markdown]
# # Upper Bound - Greedy Clique Cover

# %%
def is_clique(G, nodes):
    # Check if the subgraph induced by nodes is a clique
    return all(node in G.neighbors(neighbor) for node in nodes for neighbor in nodes if node != neighbor)

def is_neighbor_to_all(G, temp_clique, node):
    return all(node in G.neighbors(neighbor) for neighbor in temp_clique)

# %%
def clique_cover(G):
    # Create an empty set for the cover
    cover_size=  0

    # Sort the nodes by degree in descending order
    sorted_nodes = sorted(G.nodes(), key=lambda x: -G.degree(x))
    added_nodes = set()

    # Add cliques to the cover one by one
    for i, node in enumerate(sorted_nodes):
        if i % 100 == 0:
            print(f'Processing node {i} out of {len(sorted_nodes)}, added {len(added_nodes)} nodes to the cover so far.')
        # check if thge node was already added
        if node in added_nodes:
            continue

        # else we add it and a clique around it
        temp_clique = [node]
        cover_size += 1


        # order its neighbors by degree
        neighbors = sorted(G.neighbors(node), key=lambda x: -G.degree(x))

        # remove neighbors that are already in the cover
        neighbors = [neighbor for neighbor in neighbors if neighbor not in added_nodes]

        # Try adding neighbors to the clique
        for neighbor in neighbors:
            if is_neighbor_to_all(G, temp_clique, neighbor):
                temp_clique.append(neighbor)

        # Add the clique to the cover
        added_nodes.update(temp_clique)

    return cover_size

cover_size = clique_cover(graph)
print(cover_size)
# Out:
# Processing node 0 out of 49230, added 0 nodes to the cover so far.
# Processing node 100 out of 49230, added 176 nodes to the cover so far.
# Processing node 200 out of 49230, added 454 nodes to the cover so far.
# Processing node 300 out of 49230, added 668 nodes to the cover so far.
# Processing node 400 out of 49230, added 832 nodes to the cover so far.
# Processing node 500 out of 49230, added 891 nodes to the cover so far.
# Processing node 600 out of 49230, added 954 nodes to the cover so far.
# Processing node 700 out of 49230, added 1022 nodes to the cover so far.
# Processing node 800 out of 49230, added 1112 nodes to the cover so far.
# Processing node 900 out of 49230, added 1261 nodes to the cover so far.
# Processing node 1000 out of 49230, added 1435 nodes to the cover so far.
# Processing node 1100 out of 49230, added 1723 nodes to the cover so far.
# Processing node 1200 out of 49230, added 2621 nodes to the cover so far.
# Processing node 1300 out of 49230, added 3450 nodes to the cover so far.
# Processing node 1400 out of 49230, added 4485 nodes to the cover so far.
# Processing node 1500 out of 49230, added 4902 nodes to the cover so far.
# Processing node 1600 out of 49230, added 5241 nodes to the cover so far.
# Processing node 1700 out of 49230, added 5591 nodes to the cover so far.
# Processing node 1800 out of 49230, added 5690 nodes to the cover so far.
# Processing node 1900 out of 49230, added 5783 nodes to the cover so far.
# Processing node 2000 out of 49230, added 5877 nodes to the cover so far.
# Processing node 2100 out of 49230, added 6245 nodes to the cover so far.
# Processing node 2200 out of 49230, added 6480 nodes to the cover so far.
# Processing node 2300 out of 49230, added 6606 nodes to the cover so far.
# Processing node 2400 out of 49230, added 6671 nodes to the cover so far.
# Processing node 2500 out of 49230, added 6785 nodes to the cover so far.
# Processing node 2600 out of 49230, added 6801 nodes to the cover so far.
# Processing node 2700 out of 49230, added 6900 nodes to the cover so far.
# Processing node 2800 out of 49230, added 6991 nodes to the cover so far.
# Processing node 2900 out of 49230, added 7153 nodes to the cover so far.
# Processing node 3000 out of 49230, added 7261 nodes to the cover so far.
# Processing node 3100 out of 49230, added 7494 nodes to the cover so far.
# Processing node 3200 out of 49230, added 7564 nodes to the cover so far.
# Processing node 3300 out of 49230, added 7626 nodes to the cover so far.
# Processing node 3400 out of 49230, added 7752 nodes to the cover so far.
# Processing node 3500 out of 49230, added 7865 nodes to the cover so far.
# Processing node 3600 out of 49230, added 7903 nodes to the cover so far.
# Processing node 3700 out of 49230, added 7947 nodes to the cover so far.
# Processing node 3800 out of 49230, added 8001 nodes to the cover so far.
# Processing node 3900 out of 49230, added 8133 nodes to the cover so far.
# Processing node 4000 out of 49230, added 8381 nodes to the cover so far.
# Processing node 4100 out of 49230, added 8552 nodes to the cover so far.
# Processing node 4200 out of 49230, added 8601 nodes to the cover so far.
# Processing node 4300 out of 49230, added 8805 nodes to the cover so far.
# Processing node 4400 out of 49230, added 8893 nodes to the cover so far.
# Processing node 4500 out of 49230, added 8933 nodes to the cover so far.
# Processing node 4600 out of 49230, added 9083 nodes to the cover so far.
# Processing node 4700 out of 49230, added 9243 nodes to the cover so far.
# Processing node 4800 out of 49230, added 9322 nodes to the cover so far.
# Processing node 4900 out of 49230, added 9353 nodes to the cover so far.
# Processing node 5000 out of 49230, added 9415 nodes to the cover so far.
# Processing node 5100 out of 49230, added 9494 nodes to the cover so far.
# Processing node 5200 out of 49230, added 9555 nodes to the cover so far.
# Processing node 5300 out of 49230, added 9631 nodes to the cover so far.
# Processing node 5400 out of 49230, added 9690 nodes to the cover so far.
# Processing node 5500 out of 49230, added 9738 nodes to the cover so far.
# Processing node 5600 out of 49230, added 9795 nodes to the cover so far.
# Processing node 5700 out of 49230, added 9842 nodes to the cover so far.
# Processing node 5800 out of 49230, added 9898 nodes to the cover so far.
# Processing node 5900 out of 49230, added 9958 nodes to the cover so far.
# Processing node 6000 out of 49230, added 9998 nodes to the cover so far.
# Processing node 6100 out of 49230, added 10081 nodes to the cover so far.
# Processing node 6200 out of 49230, added 10194 nodes to the cover so far.
# Processing node 6300 out of 49230, added 10268 nodes to the cover so far.
# Processing node 6400 out of 49230, added 10397 nodes to the cover so far.
# Processing node 6500 out of 49230, added 10508 nodes to the cover so far.
# Processing node 6600 out of 49230, added 10532 nodes to the cover so far.
# Processing node 6700 out of 49230, added 10608 nodes to the cover so far.
# Processing node 6800 out of 49230, added 10722 nodes to the cover so far.
# Processing node 6900 out of 49230, added 10809 nodes to the cover so far.
# Processing node 7000 out of 49230, added 10862 nodes to the cover so far.
# Processing node 7100 out of 49230, added 10929 nodes to the cover so far.
# Processing node 7200 out of 49230, added 11023 nodes to the cover so far.
# Processing node 7300 out of 49230, added 11150 nodes to the cover so far.
# Processing node 7400 out of 49230, added 11234 nodes to the cover so far.
# Processing node 7500 out of 49230, added 11301 nodes to the cover so far.
# Processing node 7600 out of 49230, added 11398 nodes to the cover so far.
# Processing node 7700 out of 49230, added 11498 nodes to the cover so far.
# Processing node 7800 out of 49230, added 11549 nodes to the cover so far.
# Processing node 7900 out of 49230, added 11616 nodes to the cover so far.
# Processing node 8000 out of 49230, added 11715 nodes to the cover so far.
# Processing node 8100 out of 49230, added 11774 nodes to the cover so far.
# Processing node 8200 out of 49230, added 11840 nodes to the cover so far.
# Processing node 8300 out of 49230, added 11907 nodes to the cover so far.
# Processing node 8400 out of 49230, added 12052 nodes to the cover so far.
# Processing node 8500 out of 49230, added 12144 nodes to the cover so far.
# Processing node 8600 out of 49230, added 12216 nodes to the cover so far.
# Processing node 8700 out of 49230, added 12290 nodes to the cover so far.
# Processing node 8800 out of 49230, added 12349 nodes to the cover so far.
# Processing node 8900 out of 49230, added 12413 nodes to the cover so far.
# Processing node 9000 out of 49230, added 12492 nodes to the cover so far.
# Processing node 9100 out of 49230, added 12519 nodes to the cover so far.
# Processing node 9200 out of 49230, added 12621 nodes to the cover so far.
# Processing node 9300 out of 49230, added 12688 nodes to the cover so far.
# Processing node 9400 out of 49230, added 12784 nodes to the cover so far.
# Processing node 9500 out of 49230, added 12868 nodes to the cover so far.
# Processing node 9600 out of 49230, added 12924 nodes to the cover so far.
# Processing node 9700 out of 49230, added 13003 nodes to the cover so far.
# Processing node 9800 out of 49230, added 13085 nodes to the cover so far.
# Processing node 9900 out of 49230, added 13171 nodes to the cover so far.
# Processing node 10000 out of 49230, added 13236 nodes to the cover so far.
# Processing node 10100 out of 49230, added 13309 nodes to the cover so far.
# Processing node 10200 out of 49230, added 13383 nodes to the cover so far.
# Processing node 10300 out of 49230, added 13464 nodes to the cover so far.
# Processing node 10400 out of 49230, added 13526 nodes to the cover so far.
# Processing node 10500 out of 49230, added 13635 nodes to the cover so far.
# Processing node 10600 out of 49230, added 13736 nodes to the cover so far.
# Processing node 10700 out of 49230, added 13822 nodes to the cover so far.
# Processing node 10800 out of 49230, added 13909 nodes to the cover so far.
# Processing node 10900 out of 49230, added 14009 nodes to the cover so far.
# Processing node 11000 out of 49230, added 14103 nodes to the cover so far.
# Processing node 11100 out of 49230, added 14200 nodes to the cover so far.
# Processing node 11200 out of 49230, added 14280 nodes to the cover so far.
# Processing node 11300 out of 49230, added 14343 nodes to the cover so far.
# Processing node 11400 out of 49230, added 14414 nodes to the cover so far.
# Processing node 11500 out of 49230, added 14479 nodes to the cover so far.
# Processing node 11600 out of 49230, added 14579 nodes to the cover so far.
# Processing node 11700 out of 49230, added 14640 nodes to the cover so far.
# Processing node 11800 out of 49230, added 14736 nodes to the cover so far.
# Processing node 11900 out of 49230, added 14804 nodes to the cover so far.
# Processing node 12000 out of 49230, added 14880 nodes to the cover so far.
# Processing node 12100 out of 49230, added 15028 nodes to the cover so far.
# Processing node 12200 out of 49230, added 15116 nodes to the cover so far.
# Processing node 12300 out of 49230, added 15203 nodes to the cover so far.
# Processing node 12400 out of 49230, added 15283 nodes to the cover so far.
# Processing node 12500 out of 49230, added 15389 nodes to the cover so far.
# Processing node 12600 out of 49230, added 15485 nodes to the cover so far.
# Processing node 12700 out of 49230, added 15579 nodes to the cover so far.
# Processing node 12800 out of 49230, added 15675 nodes to the cover so far.
# Processing node 12900 out of 49230, added 15776 nodes to the cover so far.
# Processing node 13000 out of 49230, added 15860 nodes to the cover so far.
# Processing node 13100 out of 49230, added 15961 nodes to the cover so far.
# Processing node 13200 out of 49230, added 16048 nodes to the cover so far.
# Processing node 13300 out of 49230, added 16132 nodes to the cover so far.
# Processing node 13400 out of 49230, added 16216 nodes to the cover so far.
# Processing node 13500 out of 49230, added 16310 nodes to the cover so far.
# Processing node 13600 out of 49230, added 16387 nodes to the cover so far.
# Processing node 13700 out of 49230, added 16482 nodes to the cover so far.
# Processing node 13800 out of 49230, added 16563 nodes to the cover so far.
# Processing node 13900 out of 49230, added 16661 nodes to the cover so far.
# Processing node 14000 out of 49230, added 16739 nodes to the cover so far.
# Processing node 14100 out of 49230, added 16825 nodes to the cover so far.
# Processing node 14200 out of 49230, added 16901 nodes to the cover so far.
# Processing node 14300 out of 49230, added 16994 nodes to the cover so far.
# Processing node 14400 out of 49230, added 17080 nodes to the cover so far.
# Processing node 14500 out of 49230, added 17181 nodes to the cover so far.
# Processing node 14600 out of 49230, added 17269 nodes to the cover so far.
# Processing node 14700 out of 49230, added 17357 nodes to the cover so far.
# Processing node 14800 out of 49230, added 17454 nodes to the cover so far.
# Processing node 14900 out of 49230, added 17544 nodes to the cover so far.
# Processing node 15000 out of 49230, added 17618 nodes to the cover so far.
# Processing node 15100 out of 49230, added 17716 nodes to the cover so far.
# Processing node 15200 out of 49230, added 17785 nodes to the cover so far.
# Processing node 15300 out of 49230, added 17872 nodes to the cover so far.
# Processing node 15400 out of 49230, added 17958 nodes to the cover so far.
# Processing node 15500 out of 49230, added 18033 nodes to the cover so far.
# Processing node 15600 out of 49230, added 18138 nodes to the cover so far.
# Processing node 15700 out of 49230, added 18222 nodes to the cover so far.
# Processing node 15800 out of 49230, added 18309 nodes to the cover so far.
# Processing node 15900 out of 49230, added 18410 nodes to the cover so far.
# Processing node 16000 out of 49230, added 18484 nodes to the cover so far.
# Processing node 16100 out of 49230, added 18567 nodes to the cover so far.
# Processing node 16200 out of 49230, added 18643 nodes to the cover so far.
# Processing node 16300 out of 49230, added 18728 nodes to the cover so far.
# Processing node 16400 out of 49230, added 18816 nodes to the cover so far.
# Processing node 16500 out of 49230, added 18905 nodes to the cover so far.
# Processing node 16600 out of 49230, added 19001 nodes to the cover so far.
# Processing node 16700 out of 49230, added 19078 nodes to the cover so far.
# Processing node 16800 out of 49230, added 19169 nodes to the cover so far.
# Processing node 16900 out of 49230, added 19265 nodes to the cover so far.
# Processing node 17000 out of 49230, added 19354 nodes to the cover so far.
# Processing node 17100 out of 49230, added 19461 nodes to the cover so far.
# Processing node 17200 out of 49230, added 19551 nodes to the cover so far.
# Processing node 17300 out of 49230, added 19629 nodes to the cover so far.
# Processing node 17400 out of 49230, added 19748 nodes to the cover so far.
# Processing node 17500 out of 49230, added 19865 nodes to the cover so far.
# Processing node 17600 out of 49230, added 19966 nodes to the cover so far.
# Processing node 17700 out of 49230, added 20064 nodes to the cover so far.
# Processing node 17800 out of 49230, added 20160 nodes to the cover so far.
# Processing node 17900 out of 49230, added 20234 nodes to the cover so far.
# Processing node 18000 out of 49230, added 20305 nodes to the cover so far.
# Processing node 18100 out of 49230, added 20400 nodes to the cover so far.
# Processing node 18200 out of 49230, added 20491 nodes to the cover so far.
# Processing node 18300 out of 49230, added 20585 nodes to the cover so far.
# Processing node 18400 out of 49230, added 20670 nodes to the cover so far.
# Processing node 18500 out of 49230, added 20757 nodes to the cover so far.
# Processing node 18600 out of 49230, added 20842 nodes to the cover so far.
# Processing node 18700 out of 49230, added 20925 nodes to the cover so far.
# Processing node 18800 out of 49230, added 21027 nodes to the cover so far.
# Processing node 18900 out of 49230, added 21090 nodes to the cover so far.
# Processing node 19000 out of 49230, added 21186 nodes to the cover so far.
# Processing node 19100 out of 49230, added 21260 nodes to the cover so far.
# Processing node 19200 out of 49230, added 21363 nodes to the cover so far.
# Processing node 19300 out of 49230, added 21471 nodes to the cover so far.
# Processing node 19400 out of 49230, added 21558 nodes to the cover so far.
# Processing node 19500 out of 49230, added 21656 nodes to the cover so far.
# Processing node 19600 out of 49230, added 21745 nodes to the cover so far.
# Processing node 19700 out of 49230, added 21845 nodes to the cover so far.
# Processing node 19800 out of 49230, added 21949 nodes to the cover so far.
# Processing node 19900 out of 49230, added 22049 nodes to the cover so far.
# Processing node 20000 out of 49230, added 22160 nodes to the cover so far.
# Processing node 20100 out of 49230, added 22244 nodes to the cover so far.
# Processing node 20200 out of 49230, added 22331 nodes to the cover so far.
# Processing node 20300 out of 49230, added 22429 nodes to the cover so far.
# Processing node 20400 out of 49230, added 22529 nodes to the cover so far.
# Processing node 20500 out of 49230, added 22629 nodes to the cover so far.
# Processing node 20600 out of 49230, added 22726 nodes to the cover so far.
# Processing node 20700 out of 49230, added 22813 nodes to the cover so far.
# Processing node 20800 out of 49230, added 22894 nodes to the cover so far.
# Processing node 20900 out of 49230, added 23007 nodes to the cover so far.
# Processing node 21000 out of 49230, added 23080 nodes to the cover so far.
# Processing node 21100 out of 49230, added 23156 nodes to the cover so far.
# Processing node 21200 out of 49230, added 23265 nodes to the cover so far.
# Processing node 21300 out of 49230, added 23371 nodes to the cover so far.
# Processing node 21400 out of 49230, added 23484 nodes to the cover so far.
# Processing node 21500 out of 49230, added 23573 nodes to the cover so far.
# Processing node 21600 out of 49230, added 23682 nodes to the cover so far.
# Processing node 21700 out of 49230, added 23790 nodes to the cover so far.
# Processing node 21800 out of 49230, added 23908 nodes to the cover so far.
# Processing node 21900 out of 49230, added 24011 nodes to the cover so far.
# Processing node 22000 out of 49230, added 24100 nodes to the cover so far.
# Processing node 22100 out of 49230, added 24186 nodes to the cover so far.
# Processing node 22200 out of 49230, added 24268 nodes to the cover so far.
# Processing node 22300 out of 49230, added 24354 nodes to the cover so far.
# Processing node 22400 out of 49230, added 24447 nodes to the cover so far.
# Processing node 22500 out of 49230, added 24557 nodes to the cover so far.
# Processing node 22600 out of 49230, added 24648 nodes to the cover so far.
# Processing node 22700 out of 49230, added 24762 nodes to the cover so far.
# Processing node 22800 out of 49230, added 24866 nodes to the cover so far.
# Processing node 22900 out of 49230, added 24971 nodes to the cover so far.
# Processing node 23000 out of 49230, added 25074 nodes to the cover so far.
# Processing node 23100 out of 49230, added 25168 nodes to the cover so far.
# Processing node 23200 out of 49230, added 25268 nodes to the cover so far.
# Processing node 23300 out of 49230, added 25349 nodes to the cover so far.
# Processing node 23400 out of 49230, added 25441 nodes to the cover so far.
# Processing node 23500 out of 49230, added 25530 nodes to the cover so far.
# Processing node 23600 out of 49230, added 25625 nodes to the cover so far.
# Processing node 23700 out of 49230, added 25742 nodes to the cover so far.
# Processing node 23800 out of 49230, added 25830 nodes to the cover so far.
# Processing node 23900 out of 49230, added 25934 nodes to the cover so far.
# Processing node 24000 out of 49230, added 26019 nodes to the cover so far.
# Processing node 24100 out of 49230, added 26112 nodes to the cover so far.
# Processing node 24200 out of 49230, added 26208 nodes to the cover so far.
# Processing node 24300 out of 49230, added 26293 nodes to the cover so far.
# Processing node 24400 out of 49230, added 26398 nodes to the cover so far.
# Processing node 24500 out of 49230, added 26478 nodes to the cover so far.
# Processing node 24600 out of 49230, added 26565 nodes to the cover so far.
# Processing node 24700 out of 49230, added 26645 nodes to the cover so far.
# Processing node 24800 out of 49230, added 26740 nodes to the cover so far.
# Processing node 24900 out of 49230, added 26827 nodes to the cover so far.
# Processing node 25000 out of 49230, added 26936 nodes to the cover so far.
# Processing node 25100 out of 49230, added 27032 nodes to the cover so far.
# Processing node 25200 out of 49230, added 27117 nodes to the cover so far.
# Processing node 25300 out of 49230, added 27216 nodes to the cover so far.
# Processing node 25400 out of 49230, added 27304 nodes to the cover so far.
# Processing node 25500 out of 49230, added 27403 nodes to the cover so far.
# Processing node 25600 out of 49230, added 27502 nodes to the cover so far.
# Processing node 25700 out of 49230, added 27590 nodes to the cover so far.
# Processing node 25800 out of 49230, added 27706 nodes to the cover so far.
# Processing node 25900 out of 49230, added 27801 nodes to the cover so far.
# Processing node 26000 out of 49230, added 27891 nodes to the cover so far.
# Processing node 26100 out of 49230, added 27980 nodes to the cover so far.
# Processing node 26200 out of 49230, added 28071 nodes to the cover so far.
# Processing node 26300 out of 49230, added 28158 nodes to the cover so far.
# Processing node 26400 out of 49230, added 28239 nodes to the cover so far.
# Processing node 26500 out of 49230, added 28325 nodes to the cover so far.
# Processing node 26600 out of 49230, added 28423 nodes to the cover so far.
# Processing node 26700 out of 49230, added 28506 nodes to the cover so far.
# Processing node 26800 out of 49230, added 28579 nodes to the cover so far.
# Processing node 26900 out of 49230, added 28671 nodes to the cover so far.
# Processing node 27000 out of 49230, added 28764 nodes to the cover so far.
# Processing node 27100 out of 49230, added 28857 nodes to the cover so far.
# Processing node 27200 out of 49230, added 28943 nodes to the cover so far.
# Processing node 27300 out of 49230, added 29023 nodes to the cover so far.
# Processing node 27400 out of 49230, added 29121 nodes to the cover so far.
# Processing node 27500 out of 49230, added 29227 nodes to the cover so far.
# Processing node 27600 out of 49230, added 29319 nodes to the cover so far.
# Processing node 27700 out of 49230, added 29412 nodes to the cover so far.
# Processing node 27800 out of 49230, added 29510 nodes to the cover so far.
# Processing node 27900 out of 49230, added 29587 nodes to the cover so far.
# Processing node 28000 out of 49230, added 29696 nodes to the cover so far.
# Processing node 28100 out of 49230, added 29781 nodes to the cover so far.
# Processing node 28200 out of 49230, added 29874 nodes to the cover so far.
# Processing node 28300 out of 49230, added 29961 nodes to the cover so far.
# Processing node 28400 out of 49230, added 30052 nodes to the cover so far.
# Processing node 28500 out of 49230, added 30146 nodes to the cover so far.
# Processing node 28600 out of 49230, added 30235 nodes to the cover so far.
# Processing node 28700 out of 49230, added 30341 nodes to the cover so far.
# Processing node 28800 out of 49230, added 30460 nodes to the cover so far.
# Processing node 28900 out of 49230, added 30551 nodes to the cover so far.
# Processing node 29000 out of 49230, added 30643 nodes to the cover so far.
# Processing node 29100 out of 49230, added 30715 nodes to the cover so far.
# Processing node 29200 out of 49230, added 30803 nodes to the cover so far.
# Processing node 29300 out of 49230, added 30896 nodes to the cover so far.
# Processing node 29400 out of 49230, added 30985 nodes to the cover so far.
# Processing node 29500 out of 49230, added 31081 nodes to the cover so far.
# Processing node 29600 out of 49230, added 31182 nodes to the cover so far.
# Processing node 29700 out of 49230, added 31261 nodes to the cover so far.
# Processing node 29800 out of 49230, added 31358 nodes to the cover so far.
# Processing node 29900 out of 49230, added 31444 nodes to the cover so far.
# Processing node 30000 out of 49230, added 31537 nodes to the cover so far.
# Processing node 30100 out of 49230, added 31625 nodes to the cover so far.
# Processing node 30200 out of 49230, added 31712 nodes to the cover so far.
# Processing node 30300 out of 49230, added 31803 nodes to the cover so far.
# Processing node 30400 out of 49230, added 31889 nodes to the cover so far.
# Processing node 30500 out of 49230, added 31989 nodes to the cover so far.
# Processing node 30600 out of 49230, added 32074 nodes to the cover so far.
# Processing node 30700 out of 49230, added 32181 nodes to the cover so far.
# Processing node 30800 out of 49230, added 32274 nodes to the cover so far.
# Processing node 30900 out of 49230, added 32361 nodes to the cover so far.
# Processing node 31000 out of 49230, added 32459 nodes to the cover so far.
# Processing node 31100 out of 49230, added 32556 nodes to the cover so far.
# Processing node 31200 out of 49230, added 32652 nodes to the cover so far.
# Processing node 31300 out of 49230, added 32728 nodes to the cover so far.
# Processing node 31400 out of 49230, added 32807 nodes to the cover so far.
# Processing node 31500 out of 49230, added 32910 nodes to the cover so far.
# Processing node 31600 out of 49230, added 32989 nodes to the cover so far.
# Processing node 31700 out of 49230, added 33073 nodes to the cover so far.
# Processing node 31800 out of 49230, added 33172 nodes to the cover so far.
# Processing node 31900 out of 49230, added 33252 nodes to the cover so far.
# Processing node 32000 out of 49230, added 33351 nodes to the cover so far.
# Processing node 32100 out of 49230, added 33441 nodes to the cover so far.
# Processing node 32200 out of 49230, added 33532 nodes to the cover so far.
# Processing node 32300 out of 49230, added 33612 nodes to the cover so far.
# Processing node 32400 out of 49230, added 33702 nodes to the cover so far.
# Processing node 32500 out of 49230, added 33794 nodes to the cover so far.
# Processing node 32600 out of 49230, added 33888 nodes to the cover so far.
# Processing node 32700 out of 49230, added 33962 nodes to the cover so far.
# Processing node 32800 out of 49230, added 34044 nodes to the cover so far.
# Processing node 32900 out of 49230, added 34126 nodes to the cover so far.
# Processing node 33000 out of 49230, added 34209 nodes to the cover so far.
# Processing node 33100 out of 49230, added 34299 nodes to the cover so far.
# Processing node 33200 out of 49230, added 34390 nodes to the cover so far.
# Processing node 33300 out of 49230, added 34483 nodes to the cover so far.
# Processing node 33400 out of 49230, added 34571 nodes to the cover so far.
# Processing node 33500 out of 49230, added 34670 nodes to the cover so far.
# Processing node 33600 out of 49230, added 34769 nodes to the cover so far.
# Processing node 33700 out of 49230, added 34867 nodes to the cover so far.
# Processing node 33800 out of 49230, added 34953 nodes to the cover so far.
# Processing node 33900 out of 49230, added 35024 nodes to the cover so far.
# Processing node 34000 out of 49230, added 35100 nodes to the cover so far.
# Processing node 34100 out of 49230, added 35184 nodes to the cover so far.
# Processing node 34200 out of 49230, added 35271 nodes to the cover so far.
# Processing node 34300 out of 49230, added 35356 nodes to the cover so far.
# Processing node 34400 out of 49230, added 35437 nodes to the cover so far.
# Processing node 34500 out of 49230, added 35539 nodes to the cover so far.
# Processing node 34600 out of 49230, added 35632 nodes to the cover so far.
# Processing node 34700 out of 49230, added 35728 nodes to the cover so far.
# Processing node 34800 out of 49230, added 35825 nodes to the cover so far.
# Processing node 34900 out of 49230, added 35910 nodes to the cover so far.
# Processing node 35000 out of 49230, added 35994 nodes to the cover so far.
# Processing node 35100 out of 49230, added 36103 nodes to the cover so far.
# Processing node 35200 out of 49230, added 36189 nodes to the cover so far.
# Processing node 35300 out of 49230, added 36280 nodes to the cover so far.
# Processing node 35400 out of 49230, added 36363 nodes to the cover so far.
# Processing node 35500 out of 49230, added 36450 nodes to the cover so far.
# Processing node 35600 out of 49230, added 36530 nodes to the cover so far.
# Processing node 35700 out of 49230, added 36611 nodes to the cover so far.
# Processing node 35800 out of 49230, added 36692 nodes to the cover so far.
# Processing node 35900 out of 49230, added 36785 nodes to the cover so far.
# Processing node 36000 out of 49230, added 36878 nodes to the cover so far.
# Processing node 36100 out of 49230, added 36970 nodes to the cover so far.
# Processing node 36200 out of 49230, added 37066 nodes to the cover so far.
# Processing node 36300 out of 49230, added 37167 nodes to the cover so far.
# Processing node 36400 out of 49230, added 37270 nodes to the cover so far.
# Processing node 36500 out of 49230, added 37358 nodes to the cover so far.
# Processing node 36600 out of 49230, added 37444 nodes to the cover so far.
# Processing node 36700 out of 49230, added 37546 nodes to the cover so far.
# Processing node 36800 out of 49230, added 37644 nodes to the cover so far.
# Processing node 36900 out of 49230, added 37732 nodes to the cover so far.
# Processing node 37000 out of 49230, added 37817 nodes to the cover so far.
# Processing node 37100 out of 49230, added 37896 nodes to the cover so far.
# Processing node 37200 out of 49230, added 37988 nodes to the cover so far.
# Processing node 37300 out of 49230, added 38071 nodes to the cover so far.
# Processing node 37400 out of 49230, added 38159 nodes to the cover so far.
# Processing node 37500 out of 49230, added 38256 nodes to the cover so far.
# Processing node 37600 out of 49230, added 38328 nodes to the cover so far.
# Processing node 37700 out of 49230, added 38406 nodes to the cover so far.
# Processing node 37800 out of 49230, added 38491 nodes to the cover so far.
# Processing node 37900 out of 49230, added 38561 nodes to the cover so far.
# Processing node 38000 out of 49230, added 38637 nodes to the cover so far.
# Processing node 38100 out of 49230, added 38736 nodes to the cover so far.
# Processing node 38200 out of 49230, added 38831 nodes to the cover so far.
# Processing node 38300 out of 49230, added 38927 nodes to the cover so far.
# Processing node 38400 out of 49230, added 39028 nodes to the cover so far.
# Processing node 38500 out of 49230, added 39123 nodes to the cover so far.
# Processing node 38600 out of 49230, added 39215 nodes to the cover so far.
# Processing node 38700 out of 49230, added 39298 nodes to the cover so far.
# Processing node 38800 out of 49230, added 39392 nodes to the cover so far.
# Processing node 38900 out of 49230, added 39486 nodes to the cover so far.
# Processing node 39000 out of 49230, added 39579 nodes to the cover so far.
# Processing node 39100 out of 49230, added 39668 nodes to the cover so far.
# Processing node 39200 out of 49230, added 39756 nodes to the cover so far.
# Processing node 39300 out of 49230, added 39845 nodes to the cover so far.
# Processing node 39400 out of 49230, added 39932 nodes to the cover so far.
# Processing node 39500 out of 49230, added 40025 nodes to the cover so far.
# Processing node 39600 out of 49230, added 40118 nodes to the cover so far.
# Processing node 39700 out of 49230, added 40209 nodes to the cover so far.
# Processing node 39800 out of 49230, added 40295 nodes to the cover so far.
# Processing node 39900 out of 49230, added 40382 nodes to the cover so far.
# Processing node 40000 out of 49230, added 40469 nodes to the cover so far.
# Processing node 40100 out of 49230, added 40549 nodes to the cover so far.
# Processing node 40200 out of 49230, added 40648 nodes to the cover so far.
# Processing node 40300 out of 49230, added 40744 nodes to the cover so far.
# Processing node 40400 out of 49230, added 40843 nodes to the cover so far.
# Processing node 40500 out of 49230, added 40937 nodes to the cover so far.
# Processing node 40600 out of 49230, added 41028 nodes to the cover so far.
# Processing node 40700 out of 49230, added 41125 nodes to the cover so far.
# Processing node 40800 out of 49230, added 41219 nodes to the cover so far.
# Processing node 40900 out of 49230, added 41314 nodes to the cover so far.
# Processing node 41000 out of 49230, added 41397 nodes to the cover so far.
# Processing node 41100 out of 49230, added 41491 nodes to the cover so far.
# Processing node 41200 out of 49230, added 41591 nodes to the cover so far.
# Processing node 41300 out of 49230, added 41688 nodes to the cover so far.
# Processing node 41400 out of 49230, added 41777 nodes to the cover so far.
# Processing node 41500 out of 49230, added 41864 nodes to the cover so far.
# Processing node 41600 out of 49230, added 41952 nodes to the cover so far.
# Processing node 41700 out of 49230, added 42042 nodes to the cover so far.
# Processing node 41800 out of 49230, added 42129 nodes to the cover so far.
# Processing node 41900 out of 49230, added 42208 nodes to the cover so far.
# Processing node 42000 out of 49230, added 42295 nodes to the cover so far.
# Processing node 42100 out of 49230, added 42387 nodes to the cover so far.
# Processing node 42200 out of 49230, added 42478 nodes to the cover so far.
# Processing node 42300 out of 49230, added 42564 nodes to the cover so far.
# Processing node 42400 out of 49230, added 42648 nodes to the cover so far.
# Processing node 42500 out of 49230, added 42744 nodes to the cover so far.
# Processing node 42600 out of 49230, added 42838 nodes to the cover so far.
# Processing node 42700 out of 49230, added 42945 nodes to the cover so far.
# Processing node 42800 out of 49230, added 43037 nodes to the cover so far.
# Processing node 42900 out of 49230, added 43137 nodes to the cover so far.
# Processing node 43000 out of 49230, added 43240 nodes to the cover so far.
# Processing node 43100 out of 49230, added 43331 nodes to the cover so far.
# Processing node 43200 out of 49230, added 43426 nodes to the cover so far.
# Processing node 43300 out of 49230, added 43520 nodes to the cover so far.
# Processing node 43400 out of 49230, added 43618 nodes to the cover so far.
# Processing node 43500 out of 49230, added 43712 nodes to the cover so far.
# Processing node 43600 out of 49230, added 43806 nodes to the cover so far.
# Processing node 43700 out of 49230, added 43895 nodes to the cover so far.
# Processing node 43800 out of 49230, added 43986 nodes to the cover so far.
# Processing node 43900 out of 49230, added 44079 nodes to the cover so far.
# Processing node 44000 out of 49230, added 44168 nodes to the cover so far.
# Processing node 44100 out of 49230, added 44263 nodes to the cover so far.
# Processing node 44200 out of 49230, added 44348 nodes to the cover so far.
# Processing node 44300 out of 49230, added 44439 nodes to the cover so far.
# Processing node 44400 out of 49230, added 44535 nodes to the cover so far.
# Processing node 44500 out of 49230, added 44622 nodes to the cover so far.
# Processing node 44600 out of 49230, added 44717 nodes to the cover so far.
# Processing node 44700 out of 49230, added 44805 nodes to the cover so far.
# Processing node 44800 out of 49230, added 44899 nodes to the cover so far.
# Processing node 44900 out of 49230, added 44984 nodes to the cover so far.
# Processing node 45000 out of 49230, added 45078 nodes to the cover so far.
# Processing node 45100 out of 49230, added 45175 nodes to the cover so far.
# Processing node 45200 out of 49230, added 45273 nodes to the cover so far.
# Processing node 45300 out of 49230, added 45374 nodes to the cover so far.
# Processing node 45400 out of 49230, added 45474 nodes to the cover so far.
# Processing node 45500 out of 49230, added 45571 nodes to the cover so far.
# Processing node 45600 out of 49230, added 45663 nodes to the cover so far.
# Processing node 45700 out of 49230, added 45761 nodes to the cover so far.
# Processing node 45800 out of 49230, added 45862 nodes to the cover so far.
# Processing node 45900 out of 49230, added 45960 nodes to the cover so far.
# Processing node 46000 out of 49230, added 46060 nodes to the cover so far.
# Processing node 46100 out of 49230, added 46156 nodes to the cover so far.
# Processing node 46200 out of 49230, added 46250 nodes to the cover so far.
# Processing node 46300 out of 49230, added 46352 nodes to the cover so far.
# Processing node 46400 out of 49230, added 46453 nodes to the cover so far.
# Processing node 46500 out of 49230, added 46546 nodes to the cover so far.
# Processing node 46600 out of 49230, added 46644 nodes to the cover so far.
# Processing node 46700 out of 49230, added 46737 nodes to the cover so far.
# Processing node 46800 out of 49230, added 46835 nodes to the cover so far.
# Processing node 46900 out of 49230, added 46929 nodes to the cover so far.
# Processing node 47000 out of 49230, added 47027 nodes to the cover so far.
# Processing node 47100 out of 49230, added 47119 nodes to the cover so far.
# Processing node 47200 out of 49230, added 47213 nodes to the cover so far.
# Processing node 47300 out of 49230, added 47305 nodes to the cover so far.
# Processing node 47400 out of 49230, added 47400 nodes to the cover so far.
# Processing node 47500 out of 49230, added 47500 nodes to the cover so far.
# Processing node 47600 out of 49230, added 47600 nodes to the cover so far.
# Processing node 47700 out of 49230, added 47700 nodes to the cover so far.
# Processing node 47800 out of 49230, added 47800 nodes to the cover so far.
# Processing node 47900 out of 49230, added 47900 nodes to the cover so far.
# Processing node 48000 out of 49230, added 48000 nodes to the cover so far.
# Processing node 48100 out of 49230, added 48100 nodes to the cover so far.
# Processing node 48200 out of 49230, added 48200 nodes to the cover so far.
# Processing node 48300 out of 49230, added 48300 nodes to the cover so far.
# Processing node 48400 out of 49230, added 48400 nodes to the cover so far.
# Processing node 48500 out of 49230, added 48500 nodes to the cover so far.
# Processing node 48600 out of 49230, added 48600 nodes to the cover so far.
# Processing node 48700 out of 49230, added 48700 nodes to the cover so far.
# Processing node 48800 out of 49230, added 48800 nodes to the cover so far.
# Processing node 48900 out of 49230, added 48900 nodes to the cover so far.
# Processing node 49000 out of 49230, added 49000 nodes to the cover so far.
# Processing node 49100 out of 49230, added 49100 nodes to the cover so far.
# Processing node 49200 out of 49230, added 49200 nodes to the cover so far.
# 28531
